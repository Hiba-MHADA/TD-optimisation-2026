# %% [markdown]
# # Correction de l'exercice 1

# %% [markdown]
# ## 1. Définition des fonctions

# %% [markdown]
# ## Soit les fonctions réelles :
#
# \[
# \begin{aligned}
# f(x) &= 2x^2 - 3, \\
# g(x) &= x^3 - 3x^2 + 2, \\
# h(x) &= x^5 + 4x^3 + 4x.
# \end{aligned}
# \]

# %%
# TODO Import Sympy as sp


from IPython.display import display, Math

# ==========================
# 📌 Définir la variable
# ==========================
# TODO : définir x comme variable réelle
x = 

# ==========================
# 📌 Définir les fonctions
# ==========================

# TODO : f(x) = 2x^2 - 3
f = 

# TODO : g(x) = x^3 - 3x^2 + 2
g = 

# TODO : h(x) = x^5 + 4x^3 + 4x
h = 

# ==========================
# 📌 Affichage des résultats
# ==========================

print("📌 Les trois fonctions sont :\n")

display(Math(r"f(x) = " + sp.latex(f)))
# TODO : Afficher les autres fonctions
# Out:
# Les trois fonctions sont:
# $\displaystyle f(x) = 2 x^{2} - 3$
# $\displaystyle g(x) = x^{3} - 3 x^{2} + 2$
# $\displaystyle h(x) = x^{5} + 4 x^{3} + 4 x$

# %% [markdown]
# ## 2. Calcul de la dérivée première de f

# %%
# ==========================
# 📌 Calcul de la dérivée
# ==========================
# TODO : calculer la dérivée de f par rapport à x
df = 

# ==========================
# 📌 Affichage du résultat
# ==========================

# %% [markdown]
# ## 3. Développement limité de f à l’ordre 4 autour de 0

# %%
# ==========================
# 📌 Développement limité
# ==========================
# TODO : calculer le développement limité de f en 0 à l'ordre 3
DL_f = 

# ==========================
# 📌 Affichage du résultat
# ==========================
................
# Out:
# 2*x**2 - 3

# %% [markdown]
# ## 4. Tracé des courbes Cf et Cg avec Matplotlib

# %%
# ==========================
# Tracé de fonctions avec Matplotlib
# ==========================

import numpy as np
import matplotlib.pyplot as plt

# ==========================
# 📌 Génération des données
# ==========================
# TODO : générer un vecteur X de -3 à 3 avec 400 points
X = 

# ==========================
# 📌 Définition des fonctions
# ==========================
# TODO : définir Yf = f(x) = 2x² - 3
Yf = 

# TODO : définir Yg = g(x) = x³ - 3x² + 2
Yg = 

# ==========================
# 📌 Tracé des courbes
# ==========================
# TODO : tracer f(x)
plt.plot(X, )

# TODO : tracer g(x)
plt.plot(X, )

# ==========================
# 📌 Personnalisation du graphe
# ==========================
# TODO : ajouter le label de l'axe x
plt.xlabel('')

# TODO : ajouter le label de l'axe y
plt.ylabel('')

# TODO : ajouter un titre
plt.title('')

# ==========================
# 📌 Finalisation
# ==========================
# TODO : afficher la légende
plt.legend()

# TODO : activer la grille
plt.grid(True)

# TODO : afficher le graphique
plt.show()

# %% [markdown]
# ## 5. Affichage des points (0,g(0)) et (2,g(2))

# %%
# TODO : définir la fonction g(x)
g = 

# ==========================
# 📌 Domaine de tracé
# ==========================
# TODO : générer X entre -3 et 3 (400 points)
X = 

# TODO : calculer Yg (version numérique de g(x))
Yg = 

# ==========================
# 📌 Tracé de la courbe
# ==========================
# TODO : tracer la courbe de g(x)
plt.plot(X, , label='g(x)')

# ==========================
# 📌 Points particuliers
# ==========================
# TODO : calculer g(0) et g(2) avec SymPy (subs + float si besoin)
y0 = 
y2 = 

# TODO : afficher les points (0, g(0)) et (2, g(2))
plt.scatter([0, 2], [], color=None)

# ==========================
# 📌 Annotation des points
# ==========================
# TODO : ajouter texte pour le point x=0
plt.text(0, , '(0, g(0))')

# TODO : ajouter texte pour le point x=2
plt.text(2, , '(2, g(2))')

# ==========================
# 📌 Mise en forme du graphique
# ==========================
plt.xlabel('x')
plt.ylabel('y')
plt.title('Points particuliers sur g(x)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## 6. Étude de croissance de h en testant sa dérivée

# %%
# ==========================
# 📌 Définir la fonction
# ==========================
# TODO : définir la fonction h(x)
h = 

# ==========================
# 📌 Dérivation
# ==========================
# TODO : calculer la dérivée de h par rapport à x
dh = 

# ==========================
# 📌 Factorisation
# ==========================
# TODO : factoriser dh
dh_factored = 

# ==========================
# 📌 Affichage
# ==========================
dh_factored

# %% [markdown]
# ## 7. Tracé de h'(x)

# %%
# ==========================
# 📌 Variable symbolique et fonction
# ==========================
# TODO : définir x comme variable réelle SymPy
x = 

# TODO : définir la fonction h(x)
h = 

# ==========================
# 📌 Dérivée
# ==========================
# TODO : calculer la dérivée dh = h'(x)
dh = 

# ==========================
# 📌 Domaine numérique
# ==========================
# TODO : générer X entre -3 et 3 (400 points)
X = 

# ==========================
# 📌 Évaluation numérique de la dérivée
# ==========================
# TODO : calculer Ydh = dh(x) pour chaque valeur de X
Ydh = 

# ==========================
# 📌 Tracé
# ==========================
# TODO : tracer la dérivée
plt.plot(X, Ydh)

# ==========================
# 📌 Mise en forme
# ==========================
plt.xlabel('x')
plt.ylabel("h'(x)")
plt.title("Dérivée de h(x)")
plt.grid(True)

# TODO : afficher le graphique
plt.show()
